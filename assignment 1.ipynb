# %% [markdown]
# <a href="https://colab.research.google.com/github/lavananand/2303A51284.AIML.17/blob/main/assignment%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
my_list = [1, 2, 3, 4, 5]
print("Type of my_list:",(my_list))
#2
import numpy as np
array1 = np.array([1, 2, 3, 4, 5])
print("Type of array1:",(array1))
#3
print("Type of my_list:", type(my_list))
print("Type of array1:", type(array1))
#4
array2 = np.array([5, 4, 3, 2, 1])
product = array1 * array2
quotient = array1 / array2
power = array1^2
print("Product of array1 and array2:", product)
print("Quotient of array1 divided by array2:", quotient)
print("Power of array1 raised to 2:", power)
#5
import numpy as np
sum=array1+array2
print("sum of array1 and array2:",sum)
#part2
people = ['kiran', 'arun', 'vijay', 'varun']
age = [25, 30, 35, 40, 45]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(height, weight, color='blue')
plt.title('Scatter Plot: Height vs Weight')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.grid(True)
plt.show()
plt.figure(figsize=(10, 6))
plt.bar(people, height, color='green')
plt.title('Bar Chart: Height of People')
plt.xlabel('People')
plt.ylabel('Height (cm)')
plt.show()
plt.figure(figsize=(10, 6))
plt.hist(age, bins=5, color='red', edgecolor='black')
plt.title('Histogram: Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Frequency')
plt.show()
#part 3
import pandas as pd
data = {
    'Name': ['Kiran', 'Arun', 'Vijay', 'Varun'],
    'Age': [25, 30, 35, 40],
    'Height': [145, 151, 165, 173],
    'Weight': [45, 55, 65, 75]
}


# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
data = {
    'Name': ['Kiran', 'Arun', 'Vijay', 'Varun'],
    'Age': [25, 30, 35, 40],
    'Height': [145, 151, 165, 173],
    'Weight': [45, 55, 65, 75]
}


# Create a DataFrame
df = pd.DataFrame(data)
df.to_csv('/content/drive/My Drive/data.csv', index=False)
df.to_csv('/content/drive/My Drive/data.tsv', sep='\t', index=False)
df.to_excel('/content/drive/My Drive/data.xlsx', index=False)

# Step 2: Accessing the TSV file
tsv_file_path = '/content/drive/My Drive/data.tsv'
tsv_data = pd.read_csv(tsv_file_path, sep='\t')
print("Data from TSV file:")
print(tsv_data)


# Step 3: Accessing the CSV file
csv_file_path = '/content/drive/My Drive/data.csv'
csv_data = pd.read_csv(csv_file_path)

print("Data from CSV file:")
print(csv_data)


# Step 4: Accessing the Excel file
excel_file_path = '/content/drive/My Drive/data.xlsx'
excel_data = pd.read_excel(excel_file_path)
print("Data from Excel file:")
print(excel_data)



# Step 5: Accessing text data from a URL
url = 'https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv'
url_data = pd.read_csv(url)
print("Data from URL:")
print(url_data)
# Out:
# Type of my_list: [1, 2, 3, 4, 5]
# Type of array1: [1 2 3 4 5]
# Type of my_list: <class 'list'>
# Type of array1: <class 'numpy.ndarray'>
# Product of array1 and array2: [5 8 9 8 5]
# Quotient of array1 divided by array2: [0.2 0.5 1.  2.  5. ]
# Power of array1 raised to 2: [3 0 1 6 7]
# sum of array1 and array2: [6 6 6 6 6]
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Data from TSV file:
#     Name  Age  Height  Weight
# 0  Kiran   25     145      45
# 1   Arun   30     151      55
# 2  Vijay   35     165      65
# 3  Varun   40     173      75
# Data from CSV file:
#     Name  Age  Height  Weight
# 0  Kiran   25     145      45
# 1   Arun   30     151      55
# 2  Vijay   35     165      65
# 3  Varun   40     173      75
# Data from Excel file:
#     Name  Age  Height  Weight
# 0  Kiran   25     145      45
# 1   Arun   30     151      55
# 2  Vijay   35     165      65
# ...
